# %% [raw]
# **Author: Shayon Gupta**
# Aim-
# Predict whether or not a hotel was likely to receive a disproportionately high number of special requests
# This data set contains a single file which compares various booking information between two hotels: a city hotel and a resort hotel.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('hotel_bookings.csv')

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
sns.heatmap(df.corr(),cmap='coolwarm') #higher correlation with total_of_special_request is favourable

# %% [raw]
# Checking for useful features to extract

# %%
sns.barplot(x='hotel',y='total_of_special_requests',data=df,hue='children') #distinguishable

# %%
sns.barplot(x='hotel',y='total_of_special_requests',data=df,hue='babies') #distinguishable

# %%
sns.barplot(x='hotel',y='total_of_special_requests',data=df,hue='is_repeated_guest') #indistinguishable(not a useful feature)

# %%
sns.barplot(x='hotel',y='total_of_special_requests',data=df,hue='customer_type') #distinguishable
